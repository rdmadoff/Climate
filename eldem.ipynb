# %%
import rasterio as rio
import rasterio.plot

# %%
eldem = rio.open('test_dem.tif')

# %%
rasterio.plot.show(eldem)
# Out:
# <AxesSubplot:>

# %%
data=eldem.read()

# %%
data
# Out:
# array([[[ 602.6414 ,  601.8938 ,  601.87506, ...,  639.1987 ,
#           651.18866,  658.5144 ],
#         [ 604.29254,  603.70636,  602.43414, ...,  618.05414,
#           626.8119 ,  634.7081 ],
#         [ 605.77454,  605.0601 ,  604.6858 , ...,  605.922  ,
#           612.74097,  618.4602 ],
#         ...,
#         [ 941.9223 ,  896.7584 ,  863.6708 , ...,  986.272  ,
#           998.68994, 1032.4303 ],
#         [ 970.5661 ,  926.588  ,  885.7816 , ...,  977.4777 ,
#           985.1233 , 1002.88416],
#         [ 990.0103 ,  943.0018 ,  909.39685, ...,  959.11066,
#           960.8704 ,  971.4188 ]]], dtype=float32)
